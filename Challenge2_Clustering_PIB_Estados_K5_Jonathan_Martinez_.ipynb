# %% [markdown]
# <a href="https://colab.research.google.com/github/JonathanMtz1103987/Mineria-de-Datos/blob/main/Challenge2_Clustering_PIB_Estados_K5_Jonathan_Martinez_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Universidad Juárez del Estado de Durango**
# # **Facultad de Ciencias Exactas**
#
# ## **Maestría en Estadística Aplicada**
#
# ## *Clustering de PIB por Estado (México) usando todos los años (1980–2024)*
#
# ### Nombre del Estudiante: Jonathan Martinez Perez
#
# ### Fecha: Durango, DGO. 06 de febrero de 2026

# %% [markdown]
# ## Objetivo
# Agrupar **estados de México** en clusters (grupos) con base en su **trayectoria de PIB** usando todos los años disponibles (1980–2024).
# Se utilizará **k-means**, estandarización de variables y métricas para apoyar la selección de **k**.
#
# > Nota: Este notebook evita el uso de PCA para las gráficas; se usan curvas de desempeño, series de tiempo por cluster, mapas de calor y dispersogramas entre años seleccionados.

# %% [markdown]
# # Introducción
# Agregar texto aqui.

# %% [markdown]
# # 0. Ambiente de Trabajo

# %%
# ==============================================================================
# 0. Importaciones
# ==============================================================================
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from pathlib import Path

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# # 1. Carga del dataset

# %%
# ==============================
# 1. Cargar dataset
# ==============================

DATA_PATH = Path("/content/pib_mex.xlsx")

df = pd.read_excel(DATA_PATH)

print("Dimensiones (filas, columnas):", df.shape)
display(df.head())
# Out:
# Dimensiones (filas, columnas): (32, 46)
#                  Estado        1980        1981        1982        1983  \
# 0        Aguascalientes   74478.826   82816.058   83133.483   78800.571
# 1       Baja California  400156.971  451676.827  446781.453  406200.113
# 2   Baja California Sur   53015.906   57736.199   58188.199   57232.819
# 3              Campeche  511362.336  560971.276  559721.988  523134.528
# 4  Coahuila de Zaragoza  362298.762  401419.870  400947.441  372296.472
#
#          1984        1985        1986        1987        1988  ...  \
# 0   82466.825   84980.153   81602.733   84379.078   86482.199  ...
# 1  425488.625  437529.217  402275.154  414361.763  417816.039  ...
# 2   59391.459   60739.522   59879.334   61326.620   62347.413  ...
# 3  546199.162  566378.356  548649.862  570391.173  588026.452  ...
# 4  388155.755  399779.403  375949.169  384635.713  387781.177  ...
#
#          2015        2016        2017        2018        2019        2020  \
# 0  294497.175  307395.841  314242.379  327926.307  329358.364  307125.683
# 1  795080.747  828692.247  863600.649  878816.868  893946.249  839693.340
# 2  156072.034  163094.648  170784.403  184618.103  177860.750  151931.290
# 3  700310.741  663239.242  595666.960  564591.056  541962.926  500514.726
# 4  897702.095  901719.484  941581.763  966054.662  953384.334  843597.571
#
#          2021        2022        2023        2024
# 0  315233.120  314602.247  334314.666  328087.965
# 1  896313.559  919300.278  947957.519  947677.009
# 2  171064.575  178129.824  180788.204  187152.161
# 3  489604.295  472680.024  508514.617  473399.457
# 4  921586.983  935841.223  927968.193  922286.189
#
# [5 rows x 46 columns]

# %% [markdown]
# # 2. Preparación de variables

# %%
# ==============================================================================
# 2. Preparar variables (X) y etiquetas (Estado)
# ==============================================================================

# 2.1 Columnas de años (todas excepto 'Estado')
year_cols = [c for c in df.columns if c != "Estado"]

# 2.2 Ordenar columnas por año (por si vienen desordenadas)
year_cols = sorted(year_cols)

# 2.3 Matriz de variables (solo años)
X_raw = df[year_cols].copy()

# 2.4 Convertir a numérico
X_raw = X_raw.apply(pd.to_numeric, errors="coerce")

# 2.5 Manejo de faltantes: imputar con mediana por año (si existieran)
if X_raw.isna().sum().sum() > 0:
    X_raw = X_raw.fillna(X_raw.median(numeric_only=True))

# 2.6 Estandarizar StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X_raw)

# 2.7 Etiquetas (estados)
states = df["Estado"].astype(str).values

print("X:", X.shape, "| estados:", len(states), "| años:", len(year_cols))
# Out:
# X: (32, 45) | estados: 32 | años: 45

# %% [markdown]
# # 3. K-Means

# %%
# ==============================================================================
# 3. K-means con k = 5 (OBLIGATORIO)
# ==============================================================================

k = 5

kmeans = KMeans(
    n_clusters=k,
    random_state=42,
    n_init=100
)

labels = kmeans.fit_predict(X)

results = pd.DataFrame({
    "Estado": states,
    "cluster": labels
}).sort_values(["cluster", "Estado"]).reset_index(drop=True)

display(results)
# Out:
#                              Estado  cluster
# 0                           Chiapas        0
# 1                          Guerrero        0
# 2                           Hidalgo        0
# 3               Michoacan de Ocampo        0
# 4                            Oaxaca        0
# 5                         Queretaro        0
# 6                   San Luis Potosi        0
# 7                           Sinaloa        0
# 8                           Tabasco        0
# 9                  Estado de Mexico        1
# 10                          Jalisco        1
# 11                       Nuevo Leon        1
# 12                  Baja California        2
# 13                         Campeche        2
# 14                        Chihuahua        2
# 15             Coahuila de Zaragoza        2
# 16                       Guanajuato        2
# 17                           Puebla        2
# 18                           Sonora        2
# 19                       Tamaulipas        2
# 20  Veracruz de Ignacio de la Llave        2
# 21                 Ciudad de Mexico        3
# 22                   Aguascalientes        4
# 23              Baja California Sur        4
# 24                           Colima        4
# 25                          Durango        4
# 26                          Morelos        4
# 27                          Nayarit        4
# 28                     Quintana Roo        4
# 29                         Tlaxcala        4
# 30                          Yucatan        4
# 31                        Zacatecas        4

# %% [markdown]
# # 4. Métricas de Desempeño

# %%
# ==============================================================================
# 4. Métrica de desempeño (Silhouette)
# ==============================================================================

sil = silhouette_score(X, labels)
print(f"Silhouette promedio (k={k}): {sil:.4f}")
# Out:
# Silhouette promedio (k=5): 0.4997

# %% [markdown]
# # 5. Graficas

# %%
# ==============================================================================
# 5. Gráfica (SOLO UNA): Dispersión 1980 vs 2024 coloreada por cluster
# ==============================================================================

y1, y2 = 1980, 2024

x = df[y1].values
y = df[y2].values

plt.figure(figsize=(8, 7))

for c in sorted(np.unique(labels)):
    mask = (labels == c)
    plt.scatter(x[mask], y[mask], label=f"Cluster {c}")

# (Opcional) Etiquetar puntos con el nombre del estado
for i, st in enumerate(states):
    plt.text(x[i], y[i], st[:10], fontsize=7, alpha=0.7)

plt.title(f"PIB por Estado: {y1} vs {y2} (k=5)")
plt.xlabel(str(y1))
# Out:
# Text(0.5, 0, '1980')

# %% [markdown]
# # 6. Resultados

# %%
from pathlib import Path

out_path = Path("/content/resultados_kmeans_pib.xlsx")
results.to_excel(out_path, index=False)
print("Exportado:", out_path)
# Out:
# Exportado: /content/resultados_kmeans_pib.xlsx

# %% [markdown]
# # 7. Promedio por Cluster

# %%
# ==============================================================================
# 7. Promedio PIB para el 2024 por cluster
# ==============================================================================
pd.options.display.float_format = '{:,.2f}'.format

print("PIB promedio para 2024 por cluster:")

df_cluster = df.copy()
df_cluster["cluster"] = labels

display(df_cluster.groupby("cluster")[2024].mean())

pd.options.display.float_format = None

# 7.1 ¿En qué cluster está Durango?
cluster_durango = results[results["Estado"] == "Durango"]["cluster"].values[0]
print(f"Durango se encuentra en el Cluster {cluster_durango}.")

# 7.2 ¿En qué cluster está Ciudad de México?
cluster_cdmx = results[results["Estado"] == "Ciudad de Mexico"]["cluster"].values[0]
print(f"Ciudad de Mexico se encuentra en el Cluster {cluster_cdmx}.")
# Out:
# PIB promedio para 2024 por cluster:
# cluster
# 0     514,177.73
# 1   2,079,073.02
# 2     889,929.77
# 3   3,885,956.59
# 4     260,507.75
# Name: 2024, dtype: float64
# Durango se encuentra en el Cluster 4.
# Ciudad de Mexico se encuentra en el Cluster 3.

# %%
# # ============================================================================
# 7. Exportar resultados (opcional pero recomendado)
## =============================================================================
results.to_excel(out_path, index=False)
print("Exportado:", out_path)
# Out:
# Exportado: ___

# %% [markdown]
# # 8. Conclusiones
# ## Preguntas de reflexión (para entregar)
# 1. ¿Qué estados quedaron en cada cluster?
# Cluster 0:Chiapas,Guerrero,Hidalgo,Michoacán de Ocampo,Oaxaca,Querétaro,San Luis Potosí,Sinaloa,Tabasco.
# Cluster 1: Estado de México,Jalisco,Nuevo León
# Cluster 2:Baja California,Campeche,Chihuahua,Coahuila,Guanajuato,Puebla,Sonora,Tamaulipas,Veracruz.
# Cluster 3:Ciudad de Mexico.
# Cluster 4:Aguascalientes,Baja California Sur,Colima,Durango,Morelos,Nayarit,Quintana Roo,Tlaxcala,Yucatán,
# Zacatecas.
# 2. ¿Qué patrón observas en la gráfica entre 1980 y 2024?
# En la gráfica de dispersión 1980 vs 2024 se observa que existe una relacion positiva fuerte, ya que los estados con mayot PIB en 1980 tienden a mantener su ventaja en 2024. Ademas de que los clusters se separan en 2024 mas que en 1980, esto nos da a entender un crecimiento diferente entre estados y mayor divergencia económica con el tiempo.Por ultimo los clusters 0 y 4 permacecen en la parte baja de la grafica mostrando un crecimiento mas lento.
# 3. ¿El silhouette obtenido sugiere clusters bien separados o traslapados?
#  El valor fue aproximadamente de 0.50 lo que indica una separacion buena, aunque si existe un poco de traslape en los estados con PIB intermedio.
